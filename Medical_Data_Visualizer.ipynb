# %% [markdown]
# <a href="https://colab.research.google.com/github/aaziblim/Data-Analysis/blob/main/Medical_Data_Visualizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### **Draw catplot**

# %%
# Import data
df=pd.read_csv('https://raw.githubusercontent.com/freeCodeCamp/boilerplate-medical-data-visualizer/main/medical_examination.csv')

# %%
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 0          0     0       1       0
# ...

# %%
 # Add 'overweight' column
df['overweight'] = np.where(df['weight'] / ((df['height'] * 0.01) ** 2) > 25, 1, 0)

# %%
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio  overweight
# ...

# %%
# Normalize data by making 0 always good and 1 always bad
df['cholesterol'] = np.where(df['cholesterol'] == 1, 0, 1)
df['gluc'] = np.where(df['gluc'] == 1, 0, 1)

# %%
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69996  99995  22601    1     158   126.0    140     90            1     1
# 69997  99996  19066    2     183   105.0    180     90            1     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# ...

# %%
   # Create DataFrame for cat plot using 'pd.melt' using just the values from specified columns
df_cat = pd.melt(df, id_vars='cardio', value_vars=['active', 'alco', 'cholesterol', 'gluc', 'overweight', 'smoke'])

# %%
df_cat
# Out:
#         cardio variable  value
# 0            0   active      1
# 1            1   active      1
# 2            1   active      0
# 3            1   active      1
# 4            0   active      0
# ...        ...      ...    ...
# 419995       0    smoke      1
# 419996       1    smoke      0
# 419997       1    smoke      0
# 419998       1    smoke      0
# 419999       0    smoke      0
#
# [420000 rows x 3 columns]

# %%
 # Draw the catplot with 'sns.catplot()'
fig = sns.catplot(x='variable', hue='value', col='cardio', kind='count', data=df_cat)

# %%
fig.savefig('catplot.png')

# %% [markdown]
# ### **Draw heatmap**

# %%
# Import data
df = pd.read_csv('https://raw.githubusercontent.com/freeCodeCamp/boilerplate-medical-data-visualizer/main/medical_examination.csv')

# %%
  # Clean the data
df_heat = df.loc[(df['ap_lo'] <= df['ap_hi']) &
                     (df['height'] >= df['height'].quantile(0.025)) &
                     (df['height'] <= df['height'].quantile(0.975)) &
                     (df['weight'] >= df['weight'].quantile(0.025)) &
                     (df['weight'] <= df['weight'].quantile(0.975))]

# %%
df_heat
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69993  99991  19699    1     172    70.0    130     90            1     1
# 69994  99992  21074    1     165    80.0    150     80            1     1
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 0          0     0       1       0
# ...

# %%
# Calculate the correlation matrix
corr = df_heat.corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

    # Set up the matplotlib figure
fig, ax = plt.subplots(figsize=(10, 10))

# %%
 # Draw the heatmap with 'sns.heatmap()'
sns.heatmap(corr, annot=True, fmt='.1f', linewidths=0.5, mask=mask, square=True, cbar_kws={"shrink": 0.5})
# Out:
# <Axes: >

# %%
# Save image and return fig
fig.savefig('heatmap1.png')
